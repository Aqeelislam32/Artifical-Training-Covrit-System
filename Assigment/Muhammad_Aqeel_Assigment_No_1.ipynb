# %% [markdown]
# # **What is mean by arithmetic expression? Also explain different arithmetic operators?**

# %% [markdown]
# An arithmetic expression is a combination of numbers, variables, and arithmetic operators that are used to perform mathematical calculations.

# %% [markdown]
# # **Write a program to compute and print the area of a square. The formula to**compute the area of square is: area = height * width;
# # (explain each line in detail)

# %%
Height = 25
Width = 50
area = Height * Width
print(area)
# Out:
# 1250

# %% [markdown]
# # **Write a program that adds two floating point values and display the sum on the screen**

# %%
#ad the floating number
num1 = 1.5
num2 = 6.3

# Add two numbers
total_sum = num1 + num2

# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, total_sum))
# Out:
# The sum of 1.5 and 6.3 is 7.8

# %% [markdown]
# # **Write a program which get inputs numbers from user and computer the sum, average and product of these numbers**

# %%
# Take input and convert to integers
num1 = int(input("Enter first Number: "))
num2 = int(input("Enter second Number: "))
num3 = int(input("Enter third Number: "))

# Perform calculations
total = num1 + num2 + num3
average = total / 3
product = num1 * num2 * num3

# Display results
print("Sum:", total)
print("Average:", average)
print("Product:", product)
# Out:
# Enter first Number: 3
# Enter second Number: 2
# Enter third Number: 1
# Sum: 6
# Average: 2.0
# Product: 6

# %% [markdown]
# # **Write a program to inputs base and heigh of a triangle from the user. Computer the area of triangle and display result on**
# # screen. the formula to computer the area of triangle is:
# # a. Area = 1⁄2 *base* height

# %%
base = int(input('Enter the base of the triangle: '))
height = int(input('Enter the height of the triangle: '))
area = 0.5 * base * height
print('The area of the triangle is', area)
# Out:
# Enter the base of the triangle: 3
# Enter the height of the triangle: 4
# The area of the triangle is 6.0

# %% [markdown]
# # **Write a program that asks the user to enter the radiusof a circle and then** computes and displays the circle’s area. Use the
# # formula**.
# # **a. area = P1 × radius × radius*base* height**
#
# # **b. where P1 is a constant with value of 3.14159. (Note: define a constant macro P1 with #define directive)**

# %%
# Define constant PI
PI = 3.14159

# Get radius input from user and convert to float
radius = float(input("Enter the radius of the circle: "))

# Calculate area
area = PI * radius * radius

# Display result
print("The area of the circle is:", round(area, 2))
# Out:
# Enter the radius of the circle: 45
# The area of the circle is: 6361.72

# %% [markdown]
# # **Write a program that displays the ASCII code of the character entered by user**

# %%
#user enter the num and generated the ASCLL code
user  = input("Enter a character: ")
print("The ASCII value of '" + user + "' is", ord(user))
# Out:
# Enter a character: A
# The ASCII value of 'A' is 65

# %% [markdown]
# # **Write a program that input temperature from user in Celsius and converts it**
#
# # **into Fahrenheit. For conversion, use the 0following**
# formula:
#
# i. F =9/5*C+32

# %%
celsius = float(input("Enter temperature in celsius: "))
fahrenheit = (celsius * 9/5) + 32
print('%.2f Celsius is: %0.2f Fahrenheit' %(celsius, fahrenheit))
# Out:
# Enter temperature in celsius: 44
# 44.00 Celsius is: 111.20 Fahrenheit

# %% [markdown]
# # **Write a program to get the values of three sides of a triangle and calculate its area using the formula.**
#
# i. area = √s(s − a)(s − b)(s − c) where s = (a + b + c)/2

# %%
import math

# Get the lengths of the three sides from the user
a = float(input("Enter the length of side a: "))
b = float(input("Enter the length of side b: "))
c = float(input("Enter the length of side c: "))

# Calculate the semi-perimeter (s)
s = (a + b + c) / 2

# Calculate the area using Heron's formula
area = math.sqrt(s * (s - a) * (s - b) * (s - c))

# Display the result
print("The area of the triangle is:", area)
# Out:
# Enter the length of side a: 33.77
# Enter the length of side b: 66.00
# Enter the length of side c: 55.90
# The area of the triangle is: 943.5986320435588

# %% [markdown]
# # **write a program that take kilometes as input and convert in to meters**

# %%
kilometers = float(input("Enter value in kilometers: "))
conv_fac = 0.621371
miles = kilometers * conv_fac
print('%0.2f kilometers is equal to %0.2f miles' %(kilometers,miles))
# Out:
# Enter value in kilometers: 55.90
# 55.90 kilometers is equal to 34.73 miles

# %% [markdown]
# # **write a program that take three digit input from user and print in reverse order for example 123 will be printed as 321.**

# %%
# Get input from user
number = input("Enter a three-digit number: ")

# Check if the input is a three-digit number
if len(number) == 3 and number.isdigit():
  # Reverse the number
  reversed_number = number[::-1]
  # Print the reversed number
  print("The reversed number is:", reversed_number)
else:
  print("Invalid input. Please enter a three-digit number.")
# Out:
# Enter a three-digit number: 456
# The reversed number is: 654

# %% [markdown]
# # **write a program that convert inches in to centimeter**
# (centimeter = inch * 2.54)

# %%
inch = input("Enter the number")
centimeter = int(inch) * 2.54
print(centimeter)
# Out:
# Enter the number67
# 170.18

# %% [markdown]
# # **14. write a program interchange the value of two variable with each other.**

# %%
number1= 10
number2 = 20
print(f"Before swapping: number1 = {number1}, number2 = {number2}")
number1, number2 = number2, number1
print(f"After swapping: number1 = {number1}, number2 = {number2}")
# Out:
# Before swapping: number1 = 10, number2 = 20
# After swapping: number1 = 20, number2 = 10

# %% [markdown]
# # **17. Write a program which calculate the square root of give value if its positive.**

# %%
#Write a program which calculate the square root of give value if its positive.
num = int(input('Enter the Number'))

if num >= 0:
  #calculate and print the Square root
  square_root = num ** 0.5
  print(f"The square root of {num} is {square_root}")
else:
  print("Cannot calculate the square root of a negative number.")
# Out:
# Enter the Number77
# The square root of 77 is 8.774964387392123

# %%
import math

# Get input from the user
num = int(input("Enter a number: "))

# Check if the number is positive
if num >= 0:
  # Calculate and print the square root
  square_root = math.sqrt(num)
  print(f"The square root of {num} is {square_root}")
else:
  # Print a message for non-positive numbers
  print("Cannot calculate the square root of a negative number.")
# Out:
# Enter a number: 64
# The square root of 64 is 8.0

# %% [markdown]
# # **Write a program that display pass if user given marks greater than 50 otherwise print fail**

# %%
marks = int(input("Enter your marks: "))

if marks > 50:
  print("Pass")
else:
  print("Fail")
# Out:
# Enter your marks: 70
# Pass

# %% [markdown]
# # **Write a program, from if and switch, which display the message that given number is even or odd.**

# %%
# Get input from the user
num = int(input("Enter an integer: "))

# Check if the number is even or odd using the modulo operator
if num % 2 == 0:
  print(f"The number {num} is even.")
else:
  print(f"The number {num} is odd.")
# Out:
# Enter an integer: 8
# The number 8 is even.

# %% [markdown]
# # **20. Write a program which take three number from user and display the maximum number**

# %%
#

# %%
# Get three numbers from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

# Find the maximum number
maximum_number = max(num1, num2, num3)

# Display the maximum number
print(f"The maximum number is: {maximum_number}")
# Out:
# Enter the first number: 3
# Enter the second number: 4
# Enter the third number: 9
# The maximum number is: 9.0

# %% [markdown]
# # **21. Write a program perform the different arithmetic operation on two given numbers through both if else and switch statement.**

# %%
# Get two numbers from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Get the desired operation from the user
operator = input("Enter the operator (+, -, *, /): ")

# Perform the arithmetic operation based on the operator using if-elif-else
if operator == '+':
  result = num1 + num2
  print(f"{num1} + {num2} = {result}")
elif operator == '-':
  result = num1 - num2
  print(f"{num1} - {num2} = {result}")
elif operator == '*':
  result = num1 * num2
  print(f"{num1} * {num2} = {result}")
elif operator == '/':
  if num2 != 0:
    result = num1 / num2
    print(f"{num1} / {num2} = {result}")
  else:
    print("Error: Division by zero is not allowed.")
else:
  print("Invalid operator. Please enter +, -, *, or /.")
# Out:
# Enter the first number: 44
# Enter the second number: 55
# Enter the operator (+, -, *, /): *
# 44.0 * 55.0 = 2420.0

# %% [markdown]
# # **22. Write a program which take two numbers and find either they are equal to each other or not**

# %%
number1= int(input('Enter the First Number'))
number2 = int(input('Enter the Second Number'))

if number1 == number2:
  print('Both Value are Equal')
else:
  print('Both value are not Equal')
# Out:
# Enter the First Number4
# Enter the Second Number5
# Both value are not Equal

# %% [markdown]
# # **23. Write a program to find that given year is Leap year or not (leap year is divisible by 4)**

# %%
#Write a program to find that given year is Leap year or not (leap year is divisible by 4)

# %%
# Get input from the user
year = int(input("Enter a year: "))

# Check if it's a leap year
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
  print(f"{year} is a leap year.")
else:
  print(f"{year} is not a leap year.")
# Out:
# Enter a year: 12
# 12 is a leap year.

# %% [markdown]
# # **24. Write a program, through both if-else and switch, to find that given alphabet is Vowel or a Consonant.**

# %%
# Get input from the user
char = input("Enter an alphabet: ").lower()  # Convert to lowercase for easier checking

# Check if the character is a vowel using if-elif-else
if len(char) == 1 and 'a' <= char <= 'z':
  if char in ('a', 'e', 'i', 'o', 'u'):
    print(f"The character '{char}' is a vowel.")
  else:
    print(f"The character '{char}' is a consonant.")
else:
  print("Invalid input. Please enter a single alphabet character.")
# Out:
# Enter an alphabet: t
# The character 't' is a consonant.

# %% [markdown]
# # **25. Write a program, through both if-else and switch, that takes a number from 1 to 7 and display the relevant day of the week.**

# %%
# Get input from the user
day_number = int(input("Enter a number between 1 and 7: "))

# Use if-elif-else to display the day of the week
if day_number == 1:
  print("Monday")
elif day_number == 2:
  print("Tuesday")
elif day_number == 3:
  print("Wednesday")
elif day_number == 4:
  print("Thursday")
elif day_number == 5:
  print("Friday")
elif day_number == 6:
  print("Saturday")
elif day_number == 7:
  print("Sunday")
else:
  print("Invalid input. Please enter a number between 1 and 7.")
# Out:
# Enter a number between 1 and 7: 6
# Saturday

# %% [markdown]
# # **26. A school has following rules for grading system:**
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Get marks input form the user
marks = float(input('Enter the Students Marks: '))

#Determine and print the corresponding grade baes on the rules
if marks < 0 or marks > 100:
  print('Invalid marks. Please enter marks between 0 and 100.')
elif marks < 25:
  print('Grade: F')
elif marks >= 25 and marks < 45:
  print('Grade: E')
elif marks >=45 and marks < 50:
  print('Grade: D')
elif marks >= 50 and marks < 60:
  print('Grade: C')
elif marks >= 60 and marks < 80:
  print('Grade: B')
else:
  print('Grade: A')
# Out:
# Enter the Students Marks: 70
# Grade: B
